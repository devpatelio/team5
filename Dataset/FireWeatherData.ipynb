# %%
import pandas as pd
import numpy as np
firedataset = pd.read_csv('/Users/ibb4n/Downloads/FireWeatherTest/FireandLocationDataset.csv')
firedataset
# Out:
#      AcresBurned   Latitude   Longitude               Started  \
# 0           3166  34.288877 -116.941311  2013-05-01T12:38:00Z
# 1           1984  34.550480 -119.824290  2013-05-27T14:45:00Z
# 2            712  34.491490 -118.610044  2013-05-17T13:23:00Z
# 3            534  34.071556 -117.048397  2013-06-28T14:30:00Z
# 4            492  37.968660 -121.914530  2013-07-01T13:19:00Z
# ..           ...        ...         ...                   ...
# 405           13  38.757636 -120.756640  2019-07-30T19:27:46Z
# 406           12  37.606000 -121.853000  2019-10-08T17:25:12Z
# 407           12  39.328890 -121.234310  2019-06-29T22:07:59Z
# 408           11  34.033117 -117.215450  2019-10-21T08:16:33Z
# 409           10  32.762706 -117.097441  2019-10-15T17:41:57Z
#
#                                  UniqueID  StationDistance  StationID
# 0    a1b14be5-a8cf-4e40-8588-96becf4c5879         6.310176        199
# 1    abc61995-8bea-4be1-aa49-ee378ab3baaa         9.841663        107
# ...

# %%
weatherdataset = pd.read_csv('/Users/ibb4n/Downloads/FireWeatherTest/FullWeatherData.csv')
weatherdataset
# Out:
#        Stn Id              Stn Name                  CIMIS Region Month Year  \
# 0           2            FivePoints            San Joaquin Valley   Jan 2013
# 1           2            FivePoints            San Joaquin Valley   Feb 2013
# 2           2            FivePoints            San Joaquin Valley   Mar 2013
# 3           2            FivePoints            San Joaquin Valley   Apr 2013
# 4           2            FivePoints            San Joaquin Valley   May 2013
# ...       ...                   ...                           ...        ...
# 11304     261               Gazelle             Northeast Plateau   Dec 2019
# 11305     261               Gazelle             Northeast Plateau   Jan 2020
# 11306     262                Linden            San Joaquin Valley   Dec 2019
# 11307     263           Smith River           North Coast Valleys   Dec 2019
# 11308     264  Sierra Valley Center  Eastern Sierra Basin & Range   Dec 2019
#
# ...

# %%
empty_array = np.empty([410,13])
firedataset = np.append(firedataset,empty_array, axis=1)
print(firedataset.shape)
# Out:
# (410, 20)

# %%
for i in range(410):
    if "2013-01" in (firedataset[i,3]):
        firedataset[i,3] = "Jan 2013"
    elif "2013-02" in (firedataset[i,3]):
        firedataset[i,3] = "Feb 2013"
    elif "2013-03" in (firedataset[i,3]):
        firedataset[i,3] = "Mar 2013"
    elif "2013-04" in (firedataset[i,3]):
        firedataset[i,3] = "Apr 2013"
    elif "2013-05" in (firedataset[i,3]):
        firedataset[i,3] = "May 2013"
    elif "2013-06" in (firedataset[i,3]):
        firedataset[i,3] = "Jun 2013"
    elif "2013-07" in (firedataset[i,3]):
        firedataset[i,3] = "Jul 2013"
    elif "2013-08" in (firedataset[i,3]):
        firedataset[i,3] = "Aug 2013"
    elif "2013-09" in (firedataset[i,3]):
        firedataset[i,3] = "Sep 2013"
    elif "2013-10" in (firedataset[i,3]):
        firedataset[i,3] = "Oct 2013"
    elif "2013-11" in (firedataset[i,3]):
        firedataset[i,3] = "Nov 2013"
    elif "2013-12" in (firedataset[i,3]):
        firedataset[i,3] = "Dec 2013"
    elif "2014-01" in (firedataset[i,3]):
        firedataset[i,3] = "Jan 2014"
    elif "2014-02" in (firedataset[i,3]):
        firedataset[i,3] = "Feb 2014"
    elif "2014-03" in (firedataset[i,3]):
        firedataset[i,3] = "Mar 2014"
    elif "2014-04" in (firedataset[i,3]):
        firedataset[i,3] = "Apr 2014"
    elif "2014-05" in (firedataset[i,3]):
        firedataset[i,3] = "May 2014"
    elif "2014-06" in (firedataset[i,3]):
        firedataset[i,3] = "Jun 2014"
    elif "2014-07" in (firedataset[i,3]):
        firedataset[i,3] = "Jul 2014"
    elif "2014-08" in (firedataset[i,3]):
        firedataset[i,3] = "Aug 2014"
    elif "2014-09" in (firedataset[i,3]):
        firedataset[i,3] = "Sep 2014"
    elif "2014-10" in (firedataset[i,3]):
        firedataset[i,3] = "Oct 2014"
    elif "2014-11" in (firedataset[i,3]):
        firedataset[i,3] = "Nov 2014"
    elif "2014-12" in (firedataset[i,3]):
        firedataset[i,3] = "Dec 2014"
    elif "2015-01" in (firedataset[i,3]):
        firedataset[i,3] = "Jan 2015"
    elif "2015-02" in (firedataset[i,3]):
        firedataset[i,3] = "Feb 2015"
    elif "2015-03" in (firedataset[i,3]):
        firedataset[i,3] = "Mar 2015"
    elif "2015-04" in (firedataset[i,3]):
        firedataset[i,3] = "Apr 2015"
    elif "2015-05" in (firedataset[i,3]):
        firedataset[i,3] = "May 2015"
    elif "2015-06" in (firedataset[i,3]):
        firedataset[i,3] = "Jun 2015"
    elif "2015-07" in (firedataset[i,3]):
        firedataset[i,3] = "Jul 2015"
    elif "2015-08" in (firedataset[i,3]):
        firedataset[i,3] = "Aug 2015"
    elif "2015-09" in (firedataset[i,3]):
        firedataset[i,3] = "Sep 2015"
    elif "2015-10" in (firedataset[i,3]):
        firedataset[i,3] = "Oct 2015"
    elif "2015-11" in (firedataset[i,3]):
        firedataset[i,3] = "Nov 2015"
    elif "2015-12" in (firedataset[i,3]):
        firedataset[i,3] = "Dec 2015"
    elif "2016-01" in (firedataset[i,3]):
        firedataset[i,3] = "Jan 2016"
    elif "2016-02" in (firedataset[i,3]):
        firedataset[i,3] = "Feb 2016"
    elif "2016-03" in (firedataset[i,3]):
        firedataset[i,3] = "Mar 2016"
    elif "2016-04" in (firedataset[i,3]):
        firedataset[i,3] = "Apr 2016"
    elif "2016-05" in (firedataset[i,3]):
        firedataset[i,3] = "May 2016"
    elif "2016-06" in (firedataset[i,3]):
        firedataset[i,3] = "Jun 2016"
    elif "2016-07" in (firedataset[i,3]):
        firedataset[i,3] = "Jul 2016"
    elif "2016-08" in (firedataset[i,3]):
        firedataset[i,3] = "Aug 2016"
    elif "2016-09" in (firedataset[i,3]):
        firedataset[i,3] = "Sep 2016"
    elif "2016-10" in (firedataset[i,3]):
        firedataset[i,3] = "Oct 2016"
    elif "2016-11" in (firedataset[i,3]):
        firedataset[i,3] = "Nov 2016"
    elif "2016-12" in (firedataset[i,3]):
        firedataset[i,3] = "Dec 2016"
    elif "2017-01" in (firedataset[i,3]):
        firedataset[i,3] = "Jan 2017"
    elif "2017-02" in (firedataset[i,3]):
        firedataset[i,3] = "Feb 2017"
    elif "2017-03" in (firedataset[i,3]):
        firedataset[i,3] = "Mar 2017"
    elif "2017-04" in (firedataset[i,3]):
        firedataset[i,3] = "Apr 2017"
    elif "2017-05" in (firedataset[i,3]):
        firedataset[i,3] = "May 2017"
    elif "2017-06" in (firedataset[i,3]):
        firedataset[i,3] = "Jun 2017"
    elif "2017-07" in (firedataset[i,3]):
        firedataset[i,3] = "Jul 2017"
    elif "2017-08" in (firedataset[i,3]):
        firedataset[i,3] = "Aug 2017"
    elif "2017-09" in (firedataset[i,3]):
        firedataset[i,3] = "Sep 2017"
    elif "2017-10" in (firedataset[i,3]):
        firedataset[i,3] = "Oct 2017"
    elif "2017-11" in (firedataset[i,3]):
        firedataset[i,3] = "Nov 2017"
    elif "2017-12" in (firedataset[i,3]):
        firedataset[i,3] = "Dec 2017"
    elif "2018-01" in (firedataset[i,3]):
        firedataset[i,3] = "Jan 2018"
    elif "2018-02" in (firedataset[i,3]):
        firedataset[i,3] = "Feb 2018"
    elif "2018-03" in (firedataset[i,3]):
        firedataset[i,3] = "Mar 2018"
    elif "2018-04" in (firedataset[i,3]):
        firedataset[i,3] = "Apr 2018"
    elif "2018-05" in (firedataset[i,3]):
        firedataset[i,3] = "May 2018"
    elif "2018-06" in (firedataset[i,3]):
        firedataset[i,3] = "Jun 2018"
    elif "2018-07" in (firedataset[i,3]):
        firedataset[i,3] = "Jul 2018"
    elif "2018-08" in (firedataset[i,3]):
        firedataset[i,3] = "Aug 2018"
    elif "2018-09" in (firedataset[i,3]):
        firedataset[i,3] = "Sep 2018"
    elif "2018-10" in (firedataset[i,3]):
        firedataset[i,3] = "Oct 2018"
    elif "2018-11" in (firedataset[i,3]):
        firedataset[i,3] = "Nov 2018"
    elif "2018-12" in (firedataset[i,3]):
        firedataset[i,3] = "Dec 2018"
    elif "2019-01" in (firedataset[i,3]):
        firedataset[i,3] = "Jan 2019"
    elif "2019-02" in (firedataset[i,3]):
        firedataset[i,3] = "Feb 2019"
    elif "2019-03" in (firedataset[i,3]):
        firedataset[i,3] = "Mar 2019"
    elif "2019-04" in (firedataset[i,3]):
        firedataset[i,3] = "Apr 2019"
    elif "2019-05" in (firedataset[i,3]):
        firedataset[i,3] = "May 2019"
    elif "2019-06" in (firedataset[i,3]):
        firedataset[i,3] = "Jun 2019"
    elif "2019-07" in (firedataset[i,3]):
        firedataset[i,3] = "Jul 2019"
    elif "2019-08" in (firedataset[i,3]):
        firedataset[i,3] = "Aug 2019"
    elif "2019-09" in (firedataset[i,3]):
        firedataset[i,3] = "Sep 2019"
    elif "2019-10" in (firedataset[i,3]):
        firedataset[i,3] = "Oct 2019"
    elif "2019-11" in (firedataset[i,3]):
        firedataset[i,3] = "Nov 2019"
    elif "2019-12" in (firedataset[i,3]):
        firedataset[i,3] = "Dec 2019"
    else:
        print("Did not work")

# %%
weatherdataset = weatherdataset.values
print(weatherdataset[5,3])
# Out:
# Jun 2013

# %%
for y in range(410):
    for x in range(11309):
        if (firedataset[y,6] == weatherdataset[x,0]) and (firedataset[y,3] == weatherdataset[x,3]):
            firedataset[y,6:] = weatherdataset[x,3:]

# %%
for z in reversed(range(410)):
    if (firedataset[z,15]) < 10:
        firedataset = np.delete(firedataset,z,0)
print(firedataset.shape)
# Out:
# (386, 20)

# %%
import numpy
data = numpy.asarray(firedataset)
numpy.savetxt('FullDataset.csv', data, fmt='%s')
